# %% [markdown]
# <a href="https://colab.research.google.com/github/adalbertii/modele-NLP/blob/main/Huggin_Face_Hub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install huggingface_hub

# %%
from huggingface_hub import notebook_login

# %%
notebook_login()
